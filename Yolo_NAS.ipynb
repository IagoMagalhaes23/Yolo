# %% [markdown]
# <a href="https://colab.research.google.com/github/IagoMagalhaes23/Yolo/blob/main/Yolo_NAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Yolo NAS
# **- Autor:** Iago Magalhães
#
# **- Descrição:** YOLO-NAS é um modelo de detecção de objetos de última geração criado pela Deci AI. É baseado na estrutura YOLOv5 e implementa Neural Architecture Search (NAS) para determinar a arquitetura de modelo ideal para qualquer tarefa. O YOLO-NAS supera o YOLOv5 em termos de precisão e velocidade, e é mais eficiente, o que permite operar em dispositivos de menor potência.

# %% [markdown]
# ##Instalação de bibliotecas

# %%
# !pip install opencv-python torch super-gradients

# %% [markdown]
# ##Importação de bibliotecas

# %%
import cv2
import torch
from super_gradients.training import models
from google.colab.patches import cv2_imshow

# %% [markdown]
# ##Selecionando o modelo

# %%
device = 'cuda' if torch.cuda.is_available() else "cpu"

model = models.get("yolo_nas_l", pretrained_weights="coco")
# Out:
# [2024-05-01 20:49:55] WARNING - checkpoint_utils.py - :warning: The pre-trained models provided by SuperGradients may have their own licenses or terms and conditions derived from the dataset used for pre-training.
#  It is your responsibility to determine whether you have permission to use the models for your use case.
#  The model you have requested was pre-trained on the coco dataset, published under the following terms: https://cocodataset.org/#termsofuse
# [2024-05-01 20:49:55] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.
# Downloading: "https://sghub.deci.ai/models/yolo_nas_l_coco.pth" to /root/.cache/torch/hub/checkpoints/yolo_nas_l_coco.pth
# 100%|██████████| 256M/256M [00:08<00:00, 32.3MB/s]
# ...

# %% [markdown]
# ##Reconhecendo objetos em imagens

# %%
img_path = cv2.imread("/content/image.jpg")
model.predict(img_path, conf=0.25).show()
# Out:
# [2024-05-01 20:53:37] INFO - pipelines.py - Fusing some of the model's layers. If this takes too much memory, you can deactivate it by setting `fuse_model=False`

# %% [markdown]
# ##Reconhecendo objetos em videos

# %%
input_video_path = "YourInputVideoPath"
output_video_path = "YourOutputVideoPath"

model.to(device).predict(input_video_path).save(output_video_path)

# %% [markdown]
# ##Referências
# - [How to use YOLOv8 and YOLO-NAS for Object Detection](https://medium.com/@Mert.A/how-to-use-yolov8-and-yolo-nas-for-object-detection-8c5893939480)
# - [Yolo NAS](https://github.com/Deci-AI/super-gradients/blob/master/YOLONAS.md)
